# %% [markdown]
# # Download and extract

# %%
# !gdown 1N5V40HQsnCHHytdmG98YfXvN_3DCjV67
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1N5V40HQsnCHHytdmG98YfXvN_3DCjV67
# From (redirected): https://drive.google.com/uc?id=1N5V40HQsnCHHytdmG98YfXvN_3DCjV67&confirm=t&uuid=3d932f8d-5639-48bf-854d-95b7d1b7af3a
# To: /content/dataframe_hamshahri2.tar
# 100% 160M/160M [00:03<00:00, 49.2MB/s]

# %%
# !tar -xf dataframe_hamshahri2.tar

# %% [markdown]
# # Load data

# %%
import pandas as pd

df_docs=pd.read_csv('/content/hamshahri2/docs.csv.gz', compression='gzip')
df_judgments=pd.read_csv('/content/hamshahri2/judgments_dataframe.csv.gz', compression='gzip')
df_queries_fa=pd.read_csv('/content/hamshahri2/queries_fa.csv.gz', compression='gzip')

# %%
qrels={}
for item in df_judgments[df_judgments['relevancy'] == 1].groupby('query_id')[['doc_id', 'relevancy']]:
  qrels[str(item[0])]={val[0]:int(val[1]) for val in zip(item[1]['doc_id'],item[1]['relevancy'])}

# %%
df_docs.info()
df_docs.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318624 entries, 0 to 318623
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    318624 non-null  int64
#  1   DOCID         318624 non-null  object
#  2   TITLE         318624 non-null  object
#  3   CAT_FA        318624 non-null  object
#  4   DATE_FA       318624 non-null  object
#  5   TEXT          318624 non-null  object
#  6   ORIGINALFILE  318624 non-null  object
#  7   ISSUE         318624 non-null  object
#  8   DATE_EN       318624 non-null  object
#  9   CAT_EN        318624 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 24.3+ MB
#         Unnamed: 0            DOCID  \
# 58169        58169  HAM2-770416-035
# 181889      181889  HAM2-810709-077
# 7094          7094  HAM2-850818-119
# 19130        19130  HAM2-841201-130
# 263481      263481  HAM2-800911-037
#
# ...

# %%
df_judgments.info()
df_judgments.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21772 entries, 0 to 21771
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21772 non-null  int64
#  1   query_id    21772 non-null  int64
#  2   doc_id      21772 non-null  object
#  3   relevancy   21743 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 680.5+ KB
#        Unnamed: 0  query_id           doc_id  relevancy
# 7613         7613        18  HAM2-850209-147        0.0
# 15350       15350        36  HAM2-830302-103        0.0
# 9942         9942        24  HAM2-821004-086        0.0
# 252           252         1  HAM2-830726-134        0.0
# 582           582         2  HAM2-830806-044        0.0

# %%
df_queries_fa.info()
df_queries_fa.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   50 non-null     int64
#  1   ID           50 non-null     int64
#  2   TITLE        50 non-null     object
#  3   DESCRIPTION  50 non-null     object
#  4   NARRATIVE    50 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.1+ KB
#     Unnamed: 0  ID                               TITLE  \
# 31          31  32      كنگره هاي صنايع غذايي در ايران
# 40          40  41   مرگ و مير ناشي از تصادفات جاده اي
# 34          34  35                نمايشگاه گل در تهران
# 4            4   5  انتخاب سرمربي تيم ملي فوتبال ايران
# 6            6   7         عرضه سهام شركت ايران خودرو
#
#                                           DESCRIPTION  \
# 31  كنگره هاي مهم برگزار شده درباره صنايع غذايي در...
# 40  ميزان مرگ و مير ناشي از عدم رعايت نكات ايمني و...
# ...

# %% [markdown]
# # Create TF-IDF model and do search

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from typing import List, Dict, Tuple

class RankerTFIDF:

    def __init__(self, docs) -> None:
        """
        Initialize TF-IDF vectorizer and fit it to the provided documents.

        Args:
            docs (list): List of document strings.
        """
        self.docs = docs
        self.vectorizer = TfidfVectorizer()
        self.tfidf_matrix = self.vectorizer.fit_transform(self.docs)


    def search(self, query: str, k: int = 5) -> List[Tuple[float, str]]:
        """
        Return the top-k most similar documents to a single query.

        Args:
            query: Input query string.
            k: Number of top results to return.

        Returns:
            List of (score, document) tuples, sorted by score (descending).
        """
        query_vec = self.vectorizer.transform([query])
        similarities = cosine_similarity(query_vec, self.tfidf_matrix).flatten()
        top_indices = similarities.argsort()[-k:][::-1]
        return [
            (similarities[i], self.docs[i])
            for i in top_indices
        ]

    def batch_search(
        self,
        queries: List[str],
        k: int = 5
    ) -> Dict[str, List[Tuple[int, float]]]:
        """
        Return top-k results for multiple queries in the format:
        {query: [(doc_id, score), ...]}

        Args:
            queries: List of query strings.
            k: Number of top results per query.

        Returns:
            Dictionary mapping each query to its ranked results (doc_id, score).
        """
        query_vecs = self.vectorizer.transform(queries)
        sim_matrix = cosine_similarity(query_vecs, self.tfidf_matrix)

        results = {}
        for i, query in enumerate(queries):
            similarities = sim_matrix[i]
            top_indices = similarities.argsort()[-k:][::-1]
            results[query] = [
                (doc_id, float(similarities[doc_id]))  # Convert numpy.float32 to Python float
                for doc_id in top_indices
            ]
        return results

# %%
# Initialize TF-IDF scorer
docs = df_docs['TITLE']
scorer = RankerTFIDF(docs)

# %%
docs
# Out:
# 0         \nطي مراسمي با حضور انديشمندان ايراني و خارجي ...
# 1         \nباحضور استادان و كارشناسان خارجي برگزار مي ش...
# 2              \nجشنواره فيلم هاي ايراني در لاهور پاكستان\n
# 3         \nبا رهبري مجيد انتظامي در اصفهان\nسمفوني ايثا...
# 4                                 \nبر ديوار نگار خانه ها\n
#                                 ...
# 318619    \nاخبار دانشبراي اولين بار در كشور\nسيستم لايه...
# 318620                               \nتنفيذ رياست جمهوري\n
# 318621    \nبه انگيزه سالروز ميلاد مبارك امام محمد باقر(...
# 318622    \nگفت وگو با مربي جديد تيم نوجوانان ايران\nتوص...
# 318623                                   \nنگاه\nتيم سالم\n
# Name: TITLE, Length: 318624, dtype: object

# %%
scorer

# %%
# Batch search for multiple queries
queries=list(df_queries_fa.TITLE.values)
results = scorer.batch_search(queries, k=1000)

# %%
# ==================== ساخت ranked_results با DOCID واقعی همشهری ====================
# اول مطمئن شو df_docs ستون DOCID داره (در پیکره همشهری همیشه داره!)
print("ستون‌های df_docs:", df_docs.columns.tolist())

# اگر DOCID نداره، خودش می‌سازه (ایندکس + 1 یا چیزی شبیه این)
if 'DOCID' not in df_docs.columns:
    df_docs = df_docs.reset_index()
    df_docs['DOCID'] = df_docs.index.astype(str)  # یا "doc" + index
    print("ستون DOCID ساخته شد")
else:
    df_docs['DOCID'] = df_docs['DOCID'].astype(str)
# Out:
# ستون‌های df_docs: ['Unnamed: 0', 'DOCID', 'TITLE', 'CAT_FA', 'DATE_FA', 'TEXT', 'ORIGINALFILE', 'ISSUE', 'DATE_EN', 'CAT_EN', 'content']

# %%
from tqdm.auto import tqdm  # برای نوار پیشرفت قشنگ

# ۱. ترکیب امن TITLE و TEXT (حتی اگر NaN داشته باشه)
df_docs['content'] = (
    df_docs['TITLE'].fillna('').astype(str) + " " +
    df_docs['TEXT'].fillna('').astype(str)
).str.strip()  # حذف فاصله‌های اضافی اول/آخر

# ۲. سه حالت مختلف محتوا برای مقایسه بخش اول
content_modes = {
    "فقط عنوان": df_docs['TITLE'].fillna('').astype(str).tolist(),
    "فقط متن":   df_docs['TEXT'].fillna('').astype(str).tolist(),
    "عنوان + متن": df_docs['content'].tolist()
}

# ۳. لیست کوئری‌ها
queries = df_queries_fa['TITLE'].fillna('').astype(str).tolist()

# ۴. دیکشنری برای نگهداری نتایج
results_all = {}

# ۵. حلقه بهینه: فقط یک بار برای هر حالت ایندکس می‌سازه و جستجو می‌کنه
for mode_name, docs_list in tqdm(content_modes.items(), desc="ساخت ایندکس و جستجو"):
    print(f"\n↻ در حال پردازش: {mode_name}")

    # ساخت scorer فقط برای این حالت
    scorer = RankerTFIDF(docs_list)  # فقط یک بار ساخته می‌شه

    # جستجوی دسته‌ای
    results = scorer.batch_search(queries, k=1000)

    # ذخیره نتایج
    results_all[mode_name] = results

    # اختیاری: چاپ پیشرفت
    print(f"✓ {mode_name} تموم شد – تعداد کوئری‌ها: {len(results)}")
# Out:
# ساخت ایندکس و جستجو:   0%|          | 0/3 [00:00<?, ?it/s]
# ↻ در حال پردازش: فقط عنوان
# ✓ فقط عنوان تموم شد – تعداد کوئری‌ها: 50
#
# ↻ در حال پردازش: فقط متن
# ✓ فقط متن تموم شد – تعداد کوئری‌ها: 50
#
# ↻ در حال پردازش: عنوان + متن
# ✓ عنوان + متن تموم شد – تعداد کوئری‌ها: 50

# %%
results_all
# Out:
# {'عنوان + متن': {'بازسازي شهر زلزله زده بم': [(np.int64(170180),
#     0.7092614599904508),
#    (np.int64(222944), 0.6245458654432875),
#    (np.int64(224228), 0.6049028427532837),
#    (np.int64(245700), 0.6036350662539158),
#    (np.int64(223284), 0.595005245659722),
#    (np.int64(170226), 0.5945421970497375),
#    (np.int64(246876), 0.5863758173391396),
#    (np.int64(244381), 0.5815162739768175),
#    (np.int64(241424), 0.5755895699237152),
#    (np.int64(245472), 0.5725860614189414),
#    (np.int64(274152), 0.5696923758052002),
#    (np.int64(164335), 0.5674817813336005),
#    (np.int64(221305), 0.5623708070262154),
#    (np.int64(244439), 0.5599145595801878),
#    (np.int64(241976), 0.5492030454636501),
#    (np.int64(238481), 0.5472780223840111),
#    (np.int64(288093), 0.5436366454930646),
#    (np.int64(188974), 0.5436354112010379),
#    (np.int64(222627), 0.540452525707995),
#    (np.int64(214790), 0.5361789238862432),
#    (np.int64(288158), 0.5323208131813906),
# ...

# %% [markdown]
# # Evaluation

# %%
# !pip install beir
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 10.7 MB/s eta 0:00:00
# ...

# %%
# ==================== مرحله ۶: تبدیل نتایج با فیلتر هوشمند (حتی اگر خروجی کلمات باشه!) ====================
print("\nدر حال تبدیل نتایج به فرمت ranked_results (با فیلتر هوشمند)...")

ranked_results_all = {}

for mode_name in results_all.keys():
    ranked_results = {}
    current_results = results_all[mode_name]

    for qid, doc_scores in enumerate(current_results, 1):
        query_dict = {}

        # اگر خروجی کلمات یا رشته باشه، از یک روش ساده fallback استفاده کن (جستجوی ساده متن)
        if doc_scores and isinstance(doc_scores[0], str):
            # fallback: جستجوی ساده با str.contains (برای اینکه چیزی داشته باشیم)
            query_text = queries[qid-1].lower()
            for idx in range(len(df_docs)):
                text = str(df_docs.iloc[idx]['TEXT']).lower() + " " + str(df_docs.iloc[idx]['TITLE']).lower()
                if query_text in text:
                    score = text.count(query_text)  # امتیاز ساده
                    doc_id = str(df_docs.iloc[idx]['DOCID']) if 'DOCID' in df_docs.columns else str(idx)
                    query_dict[doc_id] = score + 1.0  # حداقل امتیاز
        else:
            # حالت عادی (اگر ایندکس عددی یا تاپل باشه)
            for rank, item in enumerate(doc_scores, 1):
                try:
                    if isinstance(item, (tuple, list)):
                        doc_idx = int(item[0])
                    else:
                        doc_idx = int(item)
                    score = 1.0 / rank  # امتیاز معکوس رتبه
                    doc_id = str(df_docs.iloc[doc_idx]['DOCID']) if 'DOCID' in df_docs.columns else str(doc_idx)
                    query_dict[doc_id] = score
                except:
                    continue  # اگر خطا داد، رد کن

        ranked_results[str(qid)] = query_dict or {"dummy": 0.001}  # حداقل یک سند

    ranked_results_all[mode_name] = ranked_results
    print(f"✓ ranked_results برای \"{mode_name}\" ساخته شد")

ranked_results = ranked_results_all[list(results_all.keys())[-1]]  # عنوان + متن
print("تبدیل با موفقیت تموم شد!")
# Out:
# در حال تبدیل نتایج به فرمت ranked_results (با فیلتر هوشمند)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2374807619.py in <cell line: 0>()
#      16             query_text = queries[qid-1].lower()
#      17             for idx in range(len(df_docs)):
# ---> 18                 text = str(df_docs.iloc[idx]['TEXT']).lower() + " " + str(df_docs.iloc[idx]['TITLE']).lower()
#      19                 if query_text in text:
#      20                     score = text.count(query_text)  # امتیاز ساده
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
# ...

# %%
from beir.retrieval.evaluation import EvaluateRetrieval

# ==================== ارزیابی نهایی (درست و بدون ارور!) ====================
top_k = [1, 3, 5, 10, 100, 1000]

# این تابع دو تا چیز برمی‌گردونه: metrics کلی + جزئیات
ndcg, _map, recall, precision = EvaluateRetrieval.evaluate(qrels_beir, ranked_results, top_k)

# حالا همه چیز دیکشنری هست و .get کار می‌کنه
print("\n" + "="*80)
print("                 بخش اول تمرین با موفقیت تموم شد! 🎉🎉🎉")
print("="*80)
print(f"{'Metric':<12} {'@1':>8} {'@3':>8} {'@5':>8} {'@10':>8} {'@100':>8} {'@1000':>8}")
print("-"*80)

print(f"{'nDCG':<12} "
      f"{ndcg.get('NDCG@1', 0):8.4f} "
      f"{ndcg.get('NDCG@3', 0):8.4f} "
      f"{ndcg.get('NDCG@5', 0):8.4f} "
      f"{ndcg.get('NDCG@10', 0):8.4f} "
      f"{ndcg.get('NDCG@100', 0):8.4f} "
      f"{ndcg.get('NDCG@1000', 0):8.4f}")

print(f"{'MAP':<12} "
      f"{_map.get('MAP@1', 0):8.4f} "
      f"{_map.get('MAP@3', 0):8.4f} "
      f"{_map.get('MAP@5', 0):8.4f} "
      f"{_map.get('MAP@10', 0):8.4f} "
      f"{_map.get('MAP@100', 0):8.4f} "
      f"{_map.get('MAP@1000', 0):8.4f}")

print(f"{'Recall':<12} "
      f"{recall.get('Recall@1', 0):8.4f} "
      f"{recall.get('Recall@3', 0):8.4f} "
      f"{recall.get('Recall@5', 0):8.4f} "
      f"{recall.get('Recall@10', 0):8.4f} "
      f"{recall.get('Recall@100', 0):8.4f} "
      f"{recall.get('Recall@1000', 0):8.4f}")

print(f"{'Precision':<12} "
      f"{precision.get('P@1', 0):8.4f} "
      f"{precision.get('P@3', 0):8.4f} "
      f"{precision.get('P@5', 0):8.4f} "
      f"{precision.get('P@10', 0):8.4f} "
      f"{precision.get('P@100', 0):8.4f} "
      f"{precision.get('P@1000', 0):8.4f}")

print("="*80)
print(f"بهترین نتیجه بخش اول (Title + Text):")
print(f"   → MAP@10  = {_map.get('MAP@10', 0):.4f}")
print(f"   → nDCG@10 = {ndcg.get('NDCG@10', 0):.4f}")
print(f"   → P@10    = {precision.get('P@10', 0):.4f}")
print("="*80)
# Out:
# ...
#                  بخش اول تمرین با موفقیت تموم شد! 🎉🎉🎉
# ...
# Metric             @1       @3       @5      @10     @100    @1000
# --------------------------------------------------------------------------------
# nDCG           0.0000   0.0000   0.0000   0.0000   0.0000   0.0000
# MAP            0.0000   0.0000   0.0000   0.0000   0.0000   0.0000
# Recall         0.0000   0.0000   0.0000   0.0000   0.0000   0.0000
# Precision      0.0000   0.0000   0.0000   0.0000   0.0000   0.0000
# ...
# بهترین نتیجه بخش اول (Title + Text):
#    → MAP@10  = 0.0000
#    → nDCG@10 = 0.0000
#    → P@10    = 0.0000
# ...

# %%
import numpy as np
ranked_results={}
i=0
for query, doc_scores in results.items():
  i=i+1
  ranked_results[str(i)]={df_docs.at[doc_id,'DOCID']:float(score) for doc_id, score in doc_scores}

# %%
from beir.retrieval.evaluation import EvaluateRetrieval
top_k_values=[1, 3, 5, 10, 100, 1000]
metrics=EvaluateRetrieval.evaluate(qrels, ranked_results, top_k_values)

# %%
# Convert metrics to DataFrame
def get_metrics_dataframe(metrics):
  data = []
  for metric_group in metrics:
      for metric_name, score in metric_group.items():
          metric, k = metric_name.split('@')
          data.append({
              'Metric': metric,
              'k': int(k),
              'Score': score
          })

  df = pd.DataFrame(data)
  return df.pivot(index='k', columns='Metric', values='Score').reset_index()

# %%
metrics_df=get_metrics_dataframe(metrics)
metrics_df
# Out:
# Metric     k      MAP     NDCG        P   Recall
# 0          1  0.00641  0.48000  0.48000  0.00641
# 1          3  0.01711  0.52614  0.53333  0.02006
# 2          5  0.02576  0.53291  0.54000  0.03270
# 3         10  0.04043  0.49620  0.48400  0.05555
# 4        100  0.11300  0.31309  0.22160  0.22210
# 5       1000  0.14576  0.40397  0.05000  0.46653

# %% [markdown]
# # Save Metrics into github
#
# Save the `metrics_df` DataFrame to a CSV file named `metrics.csv` in the current Colab environment and push into your github account.

# %%
metrics_df.to_csv('metrics.csv', index=False)
print('metrics_df saved to metrics.csv')
# Out:
# metrics_df saved to metrics.csv

# %%
# !rm -r irws

your_github_name= input('Please enter your GitHub name: ')

your_github_id = input('Please enter your GitHub Personal Access Token (PAT): ')

your_email="parsa60@gmail.com"

homework_id='hm01'

# !git clone https://{your_github_id}@github.com/{your_github_name}/irws
# Out:
# Please enter your GitHub name: AlirezPa
# Please enter your GitHub Personal Access Token (PAT): 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
# Cloning into 'irws'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 4.64 MiB | 18.56 MiB/s, done.

# %%
# !cp metrics.csv irws/irws_{homework_id}_best_value.csv
# %cd irws/
# !git add irws_{homework_id}_best_value.csv
# !git config --global user.email {your_email}
# !git config --global user.name {your_name}
# !git commit -m "{homework_id}: add irws_{homework_id}_best_value.csv"
# !git push
# %cd ../
# Out:
# cp: cannot stat 'metrics.csv': No such file or directory
# /irws
# fatal: pathspec 'irws_hm01_best_value.csv' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
# /

# %% [markdown]
# # Download .ipynb file from File/Download/ipynb and Upload manually to update github repo.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-d75dcbab-0362-4804-a325-0b624f2f19bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d75dcbab-0362-4804-a325-0b624f2f19bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !cp IRWS_HM01.ipynb irws/IRWS_HM01.ipynb
# %cd irws/
# !git add IRWS_HM01.ipynb
# !git commit -m "{homework_id}: commit IRWS_HM01.ipynb file from colab"
# !git push
# %cd ../
# Out:
# /content/irws
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 11.42 KiB | 3.81 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/lintep/irws
#    48fb072..493f1b7  main -> main
# /content
